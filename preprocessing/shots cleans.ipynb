# %%
import pandas as pd
pd.options.display.max_columns = 100

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import PercentFormatter, FuncFormatter

plt.style.use('ggplot')

import os
import warnings

warnings.filterwarnings('ignore')

# %%
path = "/Users/navyfish/Downloads/shots"

# Initialize an empty list to store dataframes
dataframes = []

# Iterate over files in the directory
for file in os.listdir(path):
    file_path = os.path.join(path, file)
    try:
        # Read the CSV file and append the dataframe to the list
        data = pd.read_csv(file_path)
        dataframes.append(data)
        print(f"Successfully read {file}")
    except Exception as e:
        print(f"Error reading {file}: {e}")

# Concatenate all dataframes in the list
df = pd.concat(dataframes, ignore_index=True)
# Out:
# Successfully read NBA_2009_Shots.csv
# Successfully read NBA_2004_Shots.csv
# Successfully read NBA_2010_Shots.csv
# Successfully read NBA_2016_Shots.csv
# Successfully read NBA_2023_Shots.csv
# Successfully read NBA_2008_Shots.csv
# Successfully read NBA_2024_Shots.csv
# Successfully read NBA_2011_Shots.csv
# Successfully read NBA_2005_Shots.csv
# Successfully read NBA_2017_Shots.csv
# Successfully read NBA_2022_Shots.csv
# Successfully read NBA_2006_Shots.csv
# Successfully read NBA_2012_Shots.csv
# Successfully read NBA_2019_Shots.csv
# Successfully read NBA_2021_Shots.csv
# Successfully read NBA_2014_Shots.csv
# Successfully read NBA_2013_Shots.csv
# Successfully read NBA_2007_Shots.csv
# Successfully read NBA_2018_Shots.csv
# Successfully read NBA_2020_Shots.csv
# Successfully read NBA_2015_Shots.csv

# %%
# Remove duplicates
df = df.drop_duplicates()

# Group by GAME_ID, HOME_TEAM, and AWAY_TEAM, and count unique GAME_IDs
g = df.groupby(['GAME_ID', 'HOME_TEAM', 'AWAY_TEAM'])['GAME_ID'].nunique().reset_index(name='Count')

# Filter out groups where HOME_TEAM count is not equal to 1
filtered_g = g.groupby('GAME_ID').filter(lambda x: x['HOME_TEAM'].count() != 1)

# Remove rows with GAME_ID 22000000
df = df[df['GAME_ID'] != 22000000]
df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])

# %%
df
# Out:
#          SEASON_1 SEASON_2     TEAM_ID              TEAM_NAME  PLAYER_ID  \
# 0            2009  2008-09  1610612744  Golden State Warriors     201627
# 1            2009  2008-09  1610612744  Golden State Warriors     101235
# 2            2009  2008-09  1610612756           Phoenix Suns        255
# 3            2009  2008-09  1610612739    Cleveland Cavaliers     200789
# 4            2009  2008-09  1610612756           Phoenix Suns        255
# ...           ...      ...         ...                    ...        ...
# 4231257      2015  2014-15  1610612745        Houston Rockets       2730
# 4231258      2015  2014-15  1610612742       Dallas Mavericks       2199
# 4231259      2015  2014-15  1610612759      San Antonio Spurs       2225
# 4231260      2015  2014-15  1610612740   New Orleans Pelicans     203076
# 4231261      2015  2014-15  1610612747     Los Angeles Lakers       2430
#
#               PLAYER_NAME POSITION_GROUP POSITION  GAME_DATE   GAME_ID  \
# 0          Anthony Morrow              G       SG 2009-04-15  20801229
# 1        Kelenna Azubuike              F       SF 2009-04-15  20801229
# 2              Grant Hill              F       SF 2009-04-15  20801229
# 3           Daniel Gibson              G       PG 2009-04-15  20801219
# 4              Grant Hill              F       SF 2009-04-15  20801229
# ...                   ...            ...      ...        ...       ...
# 4231257     Dwight Howard              C        C 2014-10-28  21400003
# 4231258    Tyson Chandler              C        C 2014-10-28  21400002
# 4231259       Tony Parker              G       PG 2014-10-28  21400002
# 4231260     Anthony Davis              F       PF 2014-10-28  21400001
# 4231261     Carlos Boozer              F       PF 2014-10-28  21400003
#
#         HOME_TEAM AWAY_TEAM   EVENT_TYPE  SHOT_MADE           ACTION_TYPE  \
# 0             PHX       GSW    Made Shot       True    Driving Layup Shot
# 1             PHX       GSW  Missed Shot      False            Layup Shot
# 2             PHX       GSW    Made Shot       True            Layup Shot
# 3             CLE       PHI    Made Shot       True    Driving Layup Shot
# 4             PHX       GSW  Missed Shot      False             Jump Shot
# ...           ...       ...          ...        ...                   ...
# 4231257       LAL       HOU    Made Shot       True        Jump Hook Shot
# 4231258       SAS       DAL  Missed Shot      False  Alley Oop Layup shot
# 4231259       SAS       DAL  Missed Shot      False             Jump Shot
# 4231260       NOP       ORL  Missed Shot      False             Jump Shot
# 4231261       LAL       HOU  Missed Shot      False             Jump Shot
#
#               SHOT_TYPE             BASIC_ZONE         ZONE_NAME ZONE_ABB  \
# 0        2PT Field Goal        Restricted Area            Center        C
# 1        2PT Field Goal        Restricted Area            Center        C
# 2        2PT Field Goal        Restricted Area            Center        C
# 3        2PT Field Goal        Restricted Area            Center        C
# 4        2PT Field Goal              Mid-Range         Left Side        L
# ...                 ...                    ...               ...      ...
# 4231257  2PT Field Goal  In The Paint (Non-RA)            Center        C
# 4231258  2PT Field Goal        Restricted Area            Center        C
# 4231259  2PT Field Goal              Mid-Range  Left Side Center       LC
# 4231260  2PT Field Goal              Mid-Range            Center        C
# 4231261  2PT Field Goal              Mid-Range         Left Side        L
#
#               ZONE_RANGE  LOC_X  LOC_Y  SHOT_DISTANCE  QUARTER  MINS_LEFT  \
# 0        Less Than 8 ft.   -0.0   5.25              0        4          0
# 1        Less Than 8 ft.   -0.0   5.25              0        4          0
# 2        Less Than 8 ft.   -0.0   5.25              0        4          0
# 3        Less Than 8 ft.   -0.2   5.25              0        5          0
# 4               8-16 ft.    8.7   7.55              8        4          1
# ...                  ...    ...    ...            ...      ...        ...
# 4231257  Less Than 8 ft.    1.0  10.45              5        1         11
# 4231258  Less Than 8 ft.    1.0   5.85              1        1         11
# 4231259        16-24 ft.   11.4  19.75             18        1         11
# 4231260        16-24 ft.   -5.0  24.65             20        1         11
# 4231261         8-16 ft.    8.4   5.25              8        1         11
#
#          SECS_LEFT
# 0                1
# 1                9
# 2               25
# 3                4
# 4                3
# ...            ...
# 4231257         23
# 4231258         32
# 4231259         48
# 4231260         43
# 4231261         40
#
# [4230197 rows x 26 columns]

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# POSITION_GROUP    7930
# POSITION          7930
# dtype: int64

# %%
df.nunique()
# Out:
# SEASON_1             21
# SEASON_2             21
# TEAM_ID              30
# TEAM_NAME            36
# PLAYER_ID          2162
# PLAYER_NAME        2164
# POSITION_GROUP        3
# POSITION             17
# GAME_DATE          3353
# GAME_ID           25222
# HOME_TEAM            34
# AWAY_TEAM            34
# EVENT_TYPE            2
# SHOT_MADE             2
# ACTION_TYPE          70
# SHOT_TYPE             2
# BASIC_ZONE            7
# ZONE_NAME             6
# ZONE_ABB              6
# ZONE_RANGE            5
# LOC_X               951
# LOC_Y              1694
# SHOT_DISTANCE        90
# QUARTER               8
# MINS_LEFT            13
# SECS_LEFT            60
# dtype: int64

# %%
df.to_csv('/Users/navyfish/Downloads/shots/output.csv', index=False)
